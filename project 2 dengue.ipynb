# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install download

# %%
df = pd.read_csv(r'C:\Users\acer\Untitled Folder\Project 2 - dengue\dengue_features_train.csv')

# %%
df
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1      sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2      sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3      sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4      sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# ...   ...   ...         ...             ...       ...       ...       ...
# 1451   iq  2010          21      2010-05-28  0.342750  0.318900  0.256343
# 1452   iq  2010          22      2010-06-04  0.160157  0.160371  0.136043
# 1453   iq  2010          23      2010-06-11  0.247057  0.146057  0.250357
# 1454   iq  2010          24      2010-06-18  0.333914  0.245771  0.278886
# 1455   iq  2010          25      2010-06-25  0.298186  0.232971  0.274214
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...

# %%
dummies = pd.get_dummies(df['city'])

# %%
dummies.head()
# Out:
#    iq  sj
# 0   0   1
# 1   0   1
# 2   0   1
# 3   0   1
# 4   0   1

# %%
df_new = pd.concat([df,dummies],axis = 1)

# %%
df_new.hist(figsize = [30,30])
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'weekofyear'}>,
#         <AxesSubplot:title={'center':'ndvi_ne'}>,
#         <AxesSubplot:title={'center':'ndvi_nw'}>,
#         <AxesSubplot:title={'center':'ndvi_se'}>],
#        [<AxesSubplot:title={'center':'ndvi_sw'}>,
#         <AxesSubplot:title={'center':'precipitation_amt_mm'}>,
#         <AxesSubplot:title={'center':'reanalysis_air_temp_k'}>,
#         <AxesSubplot:title={'center':'reanalysis_avg_temp_k'}>,
#         <AxesSubplot:title={'center':'reanalysis_dew_point_temp_k'}>],
#        [<AxesSubplot:title={'center':'reanalysis_max_air_temp_k'}>,
#         <AxesSubplot:title={'center':'reanalysis_min_air_temp_k'}>,
#         <AxesSubplot:title={'center':'reanalysis_precip_amt_kg_per_m2'}>,
#         <AxesSubplot:title={'center':'reanalysis_relative_humidity_percent'}>,
#         <AxesSubplot:title={'center':'reanalysis_sat_precip_amt_mm'}>],
# ...

# %%
dfn = df_new.drop(['city'],axis = 1)

# %%
dfn
# Out:
#       year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0     1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1     1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2     1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3     1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4     1990          22      1990-05-28  0.196200  0.262200  0.251200
# ...    ...         ...             ...       ...       ...       ...
# 1451  2010          21      2010-05-28  0.342750  0.318900  0.256343
# 1452  2010          22      2010-06-04  0.160157  0.160371  0.136043
# 1453  2010          23      2010-06-11  0.247057  0.146057  0.250357
# 1454  2010          24      2010-06-18  0.333914  0.245771  0.278886
# 1455  2010          25      2010-06-25  0.298186  0.232971  0.274214
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# 0     0.177617                 12.42             297.572857
# ...

# %%
df_new.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# ...

# %%
dfn.isnull().sum()
# Out:
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# ...

# %% [markdown]
# ## Here we can visually find that most of the columns are normally distributed with a certain degree of skewness to the left and right. Hence we can take the mean to fill the null values

# %% [markdown]
# ## Filling null values

# %%
dfn['precipitation_amt_mm'].fillna(dfn['precipitation_amt_mm'].median(),inplace = True)
dfn['reanalysis_air_temp_k'].fillna(dfn['reanalysis_air_temp_k'].mean(),inplace = True)
dfn['reanalysis_avg_temp_k'].fillna(dfn['reanalysis_avg_temp_k'].mean(),inplace = True)
dfn['reanalysis_dew_point_temp_k'].fillna(dfn['reanalysis_dew_point_temp_k'].median(),inplace = True)
dfn['reanalysis_max_air_temp_k'].fillna(dfn['reanalysis_max_air_temp_k'].mean(),inplace = True)
dfn['reanalysis_min_air_temp_k'].fillna(dfn['reanalysis_min_air_temp_k'].median(),inplace = True)
dfn['reanalysis_precip_amt_kg_per_m2'].fillna(dfn['reanalysis_precip_amt_kg_per_m2'].median(),inplace = True)
dfn['reanalysis_relative_humidity_percent'].fillna(dfn['reanalysis_relative_humidity_percent'].mean(),inplace = True)
dfn['reanalysis_sat_precip_amt_mm'].fillna(dfn['reanalysis_sat_precip_amt_mm'].median(),inplace = True)
dfn['reanalysis_specific_humidity_g_per_kg'].fillna(dfn['reanalysis_specific_humidity_g_per_kg'].mean(),inplace = True)
dfn['reanalysis_tdtr_k'].fillna(dfn['reanalysis_tdtr_k'].median(),inplace = True)

# %%
correlation
histogram
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12820/1440395905.py in <module>
# ----> 1 correlation
#       2 histogram
#
# NameError: name 'correlation' is not defined

# %%
# %matplotlib inline
plt.style.use('ggplot')

dfn.hist(figsize = (30,30))

# %%
#median for right and left skew

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...

# %%
from scipy.stats import skew

# %%
print("Skewness for ndvi_ne : ",skew(dfn['ndvi_ne']))
print("Skewness for ndvi_nw : ",skew(dfn['ndvi_nw']))
print("Skewness for ndvi_se : ",skew(dfn['ndvi_se']))
print("Skewness for ndvi_sw : ",skew(dfn['ndvi_sw']))
print("Skewness for precipitation_amt_mm : ",skew(dfn['precipitation_amt_mm']))
print("Skewness for reanalysis_air_temp_k : ",skew(dfn['reanalysis_air_temp_k']))
print("Skewness for reanalysis_avg_temp_k : ",skew(dfn['reanalysis_avg_temp_k']))
print("Skewness for reanalysis_dew_point_temp_k : ",skew(dfn['reanalysis_dew_point_temp_k']))
print("Skewness for reanalysis_max_air_temp_k : ",skew(dfn['reanalysis_max_air_temp_k']))
print("Skewness for reanalysis_min_air_temp_k : ",skew(dfn['reanalysis_min_air_temp_k']))
print("Skewness for reanalysis_precip_amt_kg_per_m2 : ",skew(dfn['reanalysis_precip_amt_kg_per_m2']))
print("Skewness for reanalysis_relative_humidity_percent : ",skew(dfn['reanalysis_relative_humidity_percent']))
print("Skewness for reanalysis_sat_precip_amt_mm : ",skew(dfn['reanalysis_sat_precip_amt_mm']))
print("Skewness for reanalysis_specific_humidity_g_per_kg : ",skew(dfn['reanalysis_specific_humidity_g_per_kg']))
print("Skewness for reanalysis_tdtr_k : ",skew(dfn['reanalysis_tdtr_k']))
print("Skewness for station_avg_temp_c : ",skew(dfn['station_avg_temp_c']))
print("Skewness for station_diur_temp_rng_c : ",skew(dfn['station_diur_temp_rng_c']))
print("Skewness for station_max_temp_c : ",skew(dfn['station_max_temp_c']))
print("Skewness for station_min_temp_c : ",skew(dfn['station_min_temp_c']))
print("Skewness for station_precip_mm : ",skew(dfn['station_precip_mm']))
# Out:
# Skewness for ndvi_ne :  -0.1189147322778228
# Skewness for ndvi_nw :  -0.008309362446613736
# Skewness for ndvi_se :  0.5771542314404234
# Skewness for ndvi_sw :  0.759925251710551
# Skewness for precipitation_amt_mm :  1.7472937500699215
# Skewness for reanalysis_air_temp_k :  -0.08125210971255022
# Skewness for reanalysis_avg_temp_k :  -0.1900009215774726
# Skewness for reanalysis_dew_point_temp_k :  -0.7278893428370804
# Skewness for reanalysis_max_air_temp_k :  0.8493678951649654
# Skewness for reanalysis_min_air_temp_k :  -0.67872855808635
# Skewness for reanalysis_precip_amt_kg_per_m2 :  3.395095367590467
# Skewness for reanalysis_relative_humidity_percent :  0.5753028715043738
# Skewness for reanalysis_sat_precip_amt_mm :  1.7472937500699215
# Skewness for reanalysis_specific_humidity_g_per_kg :  -0.5408760084091756
# Skewness for reanalysis_tdtr_k :  1.0803438511610042
# Skewness for station_avg_temp_c :  -0.5758338277029801
# ...

# %%
"""from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()"""
# Out:
# 'from sklearn.preprocessing import MinMaxScaler\nscaler = MinMaxScaler()'

# %%
"""%matplotlib inline
plt.plot(dfn['week_start_date'],dfn['ndvi_ne'])
plt.show()"""
# Out:
# "%matplotlib inline\nplt.plot(dfn['week_start_date'],dfn['ndvi_ne'])\nplt.show()"

# %%
# %matplotlib inline
ax = dfn.plot(x='week_start_date',kind = 'line',figsize=(18,90),subplots=True)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#Multiplicative decomposition
mul_result = seasonal_decompose(dfn['reanalysis_air_temp_k'], model = 'multiplicative',period = 1)
#dfn.drop(['year','weekofyear','week_start_date']
#Additive decomposition
#add_result = seasonal_decompose(dfn,model = 'additive' , period = 1)

# %%
d = pd.concat([mul_result.seasonal,mul_result.trend,mul_result.resid,mul_result.observed],axis = 1)
d.columns = ['seasonality','trend','residual','actual_values']
d
# Out:
#       seasonality       trend  residual  actual_values
# 0             1.0  297.572857       1.0     297.572857
# 1             1.0  298.211429       1.0     298.211429
# 2             1.0  298.781429       1.0     298.781429
# 3             1.0  298.987143       1.0     298.987143
# 4             1.0  299.518571       1.0     299.518571
# ...           ...         ...       ...            ...
# 1451          1.0  299.334286       1.0     299.334286
# 1452          1.0  298.330000       1.0     298.330000
# 1453          1.0  296.598571       1.0     296.598571
# 1454          1.0  296.345714       1.0     296.345714
# 1455          1.0  298.097143       1.0     298.097143
#
# [1456 rows x 4 columns]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
dff = dfn.drop(['year','weekofyear','week_start_date'],axis = 1)
adf = {}
for col in dff.columns.values:
    adf[col] = adfuller(dff[col])
    print(" \n",col,adf[col])
# Out:
#
#  ndvi_ne (-2.1124889244598943, 0.23952248653228042, 21, 1434, {'1%': -3.434918371231736, '5%': -2.8635576234668982, '10%': -2.5678441693558898}, -2775.930101847968)
#
#  ndvi_nw (-3.5565952558183787, 0.006647155324575871, 9, 1446, {'1%': -3.434880391815318, '5%': -2.8635408625359315, '10%': -2.5678352438452814}, -3297.1123941872056)
#
#  ndvi_se (-5.486960009938162, 2.2188614387020316e-06, 11, 1444, {'1%': -3.434886677803751, '5%': -2.8635436366589673, '10%': -2.5678367211155533}, -3787.051942249669)
#
#  ndvi_sw (-4.583050757066367, 0.0001387871406279579, 11, 1444, {'1%': -3.434886677803751, '5%': -2.8635436366589673, '10%': -2.5678367211155533}, -3605.141579844524)
#
#  precipitation_amt_mm (-8.950608002516779, 8.744673587588249e-15, 6, 1449, {'1%': -3.4348709954268384, '5%': -2.863536715724964, '10%': -2.567833035595811}, 14668.467521787365)
#
# ...
